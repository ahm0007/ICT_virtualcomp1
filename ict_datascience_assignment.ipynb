# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#1. Read the dataset to python environment.
data1=pd.read_excel(r"C:\Users\sakthi\Downloads\iris.xls")

# %%
#2. Display the columns in the dataset.

data1.head(150)
# Out:
#       SL   SW   PL   PW  Classification
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
#3. Calculate the mean of each column of the dataset.

data1.loc[:,["SL"]].mean()
# Out:
# SL    5.843333
# dtype: float64

# %%
data1.loc[:,["SW"]].mean()
# Out:
# SW    3.054
# dtype: float64

# %%
data1.loc[:,["PL"]].mean()
# Out:
# PL    3.758667
# dtype: float64

# %%
data1.loc[:,["PW"]].mean()
# Out:
# PW    1.198667
# dtype: float64

# %%
#4. Check for the null values present in the dataset.

null_val=pd.isnull(data1["SL"])
data1[null_val]
# Out:
# Empty DataFrame
# Columns: [SL, SW, PL, PW, Classification]
# Index: []

# %%
#5. Perform meaningful visualizations using the dataset. Bring at least 3 
# visualizations.

plt.hist(data1["SL"],data1["SW"] color="purple", cumulative=True)
plt.show()
# Out:
#   File "C:\Users\sakthi\AppData\Local\Temp\ipykernel_3008\2220208063.py", line 4
#     plt.hist(data1["SL"],data1["SW"] color="purple", cumulative=True)
#                                      ^
# SyntaxError: invalid syntax

# %%
data1["SW"].plot.bar()
plt.show()

# %%
sns.scatterplot(x="SL",y="SW",hue="Classification",data=data1)
plt.xlabel("sepal length")
plt.ylabel("sepal width")
plt.title("sepal lenght vs sepal width")
plt.show()

# %%
# create a bar graph with different colors for each species
data1[["SW","SL","PW","PL"]].plot.bar()
#plt.figure(figsize=(100,6))
plt.xticks(rotation=90)
plt.show()

# %%
sns.pairplot(data1)

# %%
sns.heatmap(data1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3008\3207864676.py in <module>
# ----> 1 sns.heatmap(data1)
#
# ~\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\anaconda3\lib\site-packages\seaborn\matrix.py in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     538     """
#     539     # Initialize the plotter object
# --> 540     plotter = _HeatMapper(data, vmin, vmax, cmap, center, robust, annot, fmt,
#     541                           annot_kws, cbar, cbar_kws, xticklabels,
# ...
